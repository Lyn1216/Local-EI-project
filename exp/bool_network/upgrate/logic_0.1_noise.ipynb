# %%
import load_database13 as db
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from grn_tpm import text_bn_graph

# %%
condi_sys = [0, 2, 4]
ACE_tpm, ACE_un, ACE_syn, ACE_vividness, onenote_tpm_result, onenote_un_result, onenote_syn_result, onenote_vividness_result = text_bn_graph(textfile = 'Example/6note_OR_XOR.txt', condidate_sys=condi_sys, fill_onenode=True, noise=0.1, save_onenote = True)
# Out:
# all intrinsic variables: A,B,C,D,E,F
# external parameters:
# mechanism:    A,C,E
# environment:    A,B,C,E
# [[0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]]
# un:  0.27288075493534997
# ...

# %%
condi_sys = [1, 3, 5]
BDF_tpm, BDF_un, BDF_syn, BDF_vividness, _, _, _, _ = text_bn_graph(textfile = 'Example/6note_OR_XOR.txt', condidate_sys=condi_sys, fill_onenode=True, noise=0.1, save_onenote = True)
# Out:
# all intrinsic variables: A,B,C,D,E,F
# external parameters:
# mechanism:    B,D,F
# environment:    A,B,D,F
# [[0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]]
# un:  0.41067253432539225
# ...

# %%
ACE_un, ACE_syn, ACE_vividness
# Out:
# (0.27288075493534997, 0.10472625297141264, 0.3776070079067626)

# %%
BDF_un, BDF_syn, BDF_vividness
# Out:
# (0.41067253432539225, 0.8624177306350442, 1.2730902649604365)

# %%
onenote_un_result, onenote_syn_result, onenote_vividness_result
# Out:
# ({'A': 0.014378460478078663,
#   'B': 0.0,
#   'C': 0.04678484847737542,
#   'D': 0.0,
#   'E': 0.04678484847737542,
#   'F': 0.0},
#  {'A': 0.0519970903232612,
#   'B': 0.5310044064107188,
#   'C': 0.0859662531253043,
#   'D': 0.5310044064107189,
#   'E': 0.0859662531253043,
#   'F': 0.5310044064107189},
#  {'A': 0.06637555080133986,
#   'B': 0.5310044064107188,
#   'C': 0.13275110160267972,
#   'D': 0.5310044064107189,
#   'E': 0.13275110160267972,
#   'F': 0.5310044064107189})
