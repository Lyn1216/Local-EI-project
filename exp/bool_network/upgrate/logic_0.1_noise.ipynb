# %%
import sys
sys.path.append("..")
import grn.load_database13 as db
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from grn.grn_tpm import text_bn_graph

# %%
candi_sys = [0, 2, 4]
ACE_tpm,ACE_un,ACE_syn,ACE_vividness,onenote_tpm_result, onenote_un_result,onenote_syn_result,onenote_vividness_result=\
    text_bn_graph(textfile='Example/6note_OR_XOR.txt',candidate_sys=candi_sys,fill_onenode=True,noise=0.1,save_onenote=True)
# Out:
# all intrinsic variables: A,B,C,D,E,F
# external parameters:
# mechanism:    A,C,E
# [0, 2, 4, 1]
# new_arr
# [0. 1. 2. 4.]
# new_arr
# [1 0 2 4]
# new_arr
# [1 0 2 4]
# tpm:
# [[0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
# ...

# %%
candi_sys = [1, 3, 5]
BDF_tpm,BDF_un,BDF_syn,BDF_vividness, _, _, _, _=\
    text_bn_graph(textfile='Example/6note_OR_XOR.txt',candidate_sys=candi_sys,fill_onenode=True,noise=0.1,save_onenote=True)
# Out:
# all intrinsic variables: A,B,C,D,E,F
# external parameters:
# mechanism:    B,D,F
# [1, 3, 5, 0]
# new_arr
# [0. 1. 3. 5.]
# new_arr
# [0 1 3 5]
# new_arr
# [0 1 3 5]
# tpm:
# [[0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]
#  [0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
#  [0.009 0.081 0.081 0.729 0.001 0.009 0.009 0.081]
#  [0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.729 0.081 0.081 0.009 0.081 0.009 0.009 0.001]
#  [0.081 0.009 0.009 0.001 0.729 0.081 0.081 0.009]
#  [0.001 0.009 0.009 0.081 0.009 0.081 0.081 0.729]
# ...

# %%
ACE_un, ACE_syn, ACE_vividness
# Out:
# (0.40706815278210534, 0.015262534919747883, 0.4223306877018532)

# %%
BDF_un, BDF_syn, BDF_vividness
# Out:
# (0.7420858585497175, 0.1203318720853267, 0.8624177306350442)

# %%
onenote_un_result, onenote_syn_result, onenote_vividness_result
# Out:
# ({'A': 0.014378460478078663,
#   'B': 0.0,
#   'C': 0.04678484847737542,
#   'D': 0.0,
#   'E': 0.04678484847737542,
#   'F': 0.0},
#  {'A': 0.0519970903232612,
#   'B': 0.5310044064107188,
#   'C': 0.0859662531253043,
#   'D': 0.5310044064107189,
#   'E': 0.0859662531253043,
#   'F': 0.5310044064107189},
#  {'A': 0.06637555080133986,
#   'B': 0.5310044064107188,
#   'C': 0.13275110160267972,
#   'D': 0.5310044064107189,
#   'E': 0.13275110160267972,
#   'F': 0.5310044064107189})
